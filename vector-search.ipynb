# %% [markdown]
# ## **Vector search**

# %% [markdown]
# ## Introduction to Vector Search
#
# Modern applications like recommendation systems, chatbots, and search engines need to handle **unstructured data** such as text, images, audio, and video.
# Traditional search (keyword or SQL-based) struggles here, which is why **Vector Search** is used.
#
#
# ### What is a Vector?
#
# - A **vector** is simply a list of numbers (like `[0.2, -0.4, 1.7, ...]`).
# - In machine learning, vectors are used to represent **features** of data.
#
# Examples:
# - A sentence can be converted into a vector that captures its meaning (using embeddings like Word2Vec, BERT, etc.).
# - An image can be converted into a vector that represents its visual features.
#
# These vectors usually live in **high-dimensional space** (e.g., 128D, 512D, 1024D).
#
#
#
# ### What is Vector Search?
#
# **Vector Search** is a technique to find the most similar items to a given query based on their vector representations.
#
# - Instead of looking for exact matches (`WHERE name = 'Alice'`),
#   vector search finds items that are **closest in meaning or similarity**.
# - It uses **mathematical distance** (cosine similarity, Euclidean distance, etc.) to compare vectors.
#
# Example:
# If you search for *"puppy"*, results may include *"dog"*, *"cute pet"*, *"golden retriever"*—because their vectors are close in meaning.
#
#
#
# ### Why Use Vector Search?
#
# Traditional search:
# - Works well for structured data and exact keywords.
# - Struggles with synonyms, context, or unstructured data.
#
# Vector search:
# - Handles **semantic similarity**.
# - Works with **text, images, and other unstructured formats**.
# - Powers modern systems like:
#   - Google Search (*related queries*)
#   - ChatGPT knowledge retrieval
#   - Netflix & Spotify recommendations
#   - Image similarity search
#
#
# ### How Vector Search Works
#
# 1. **Data Encoding (Embeddings)**
#    Convert text, image, or audio into numerical vectors using a model.
#
# 2. **Vector Database**
#    Store all vectors in a specialized database (e.g., Pinecone, Milvus, Weaviate, FAISS).
#
# 3. **Similarity Search**
#    Convert the query into a vector and compare it with stored vectors.
#
# 4. **Return Results**
#    Retrieve items whose vectors are most similar to the query.
#
#
#
# ### Similarity Metrics
#
# - **Cosine Similarity** → angle between vectors.
# - **Euclidean Distance** → straight-line distance.
# - **Dot Product** → magnitude & alignment.
#
# ##### Example (Text Search)
#
# | Sentence          | Vector (simplified) |
# |-------------------|----------------------|
# | "I love cats"     | [0.2, 0.8, 0.5]     |
# | "Dogs are cute"   | [0.3, 0.7, 0.6]     |
# | "Pizza is tasty"  | [0.9, 0.1, 0.2]     |
#
# If query = "I like kittens" → vector ≈ [0.25, 0.75, 0.55]
# Closest matches = **"I love cats"** and **"Dogs are cute"**
#
#
#
# #### Tools for Vector Search
#
# - **Vector Databases**: Pinecone, Milvus, Weaviate
# - **Libraries**: FAISS (Facebook AI), Annoy, ScaNN
# - **Cloud Services**: Elasticsearch (with vector search), OpenSearch, Vespa
#
# ## Summary
#
# - **Vector Search = similarity search in high-dimensional space.**
# - It’s essential for handling **unstructured data** (text, images, audio).
# - Core idea: **represent data as vectors → compare similarity → return nearest neighbors.**

# %%
# !pip install langchain chromadb sentence-transformers langchain_community
# Out:
# Requirement already satisfied: langchain in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (0.3.27)
# Requirement already satisfied: chromadb in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (1.0.15)
# Requirement already satisfied: sentence-transformers in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (5.0.0)
# Requirement already satisfied: langchain_community in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (0.3.27)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.72 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from langchain) (0.3.72)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from langchain) (0.3.9)
# Requirement already satisfied: langsmith>=0.1.17 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from langchain) (0.4.10)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from langchain) (2.11.7)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from langchain) (2.0.42)
# Requirement already satisfied: requests<3,>=2 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from langchain) (2.32.4)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from langchain) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (1.33)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (4.14.1)
# Requirement already satisfied: packaging>=23.2 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (25.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.72->langchain) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from requests<3,>=2->langchain) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from requests<3,>=2->langchain) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from requests<3,>=2->langchain) (2025.8.3)
# Requirement already satisfied: greenlet>=1 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.2.3)
# Requirement already satisfied: build>=1.0.3 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from chromadb) (1.3.0)
# Requirement already satisfied: pybase64>=1.4.1 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from chromadb) (1.4.2)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.35.0)
# Requirement already satisfied: numpy>=1.22.5 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from chromadb) (2.3.2)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from chromadb) (5.4.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from chromadb) (1.22.1)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from chromadb) (1.36.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from chromadb) (1.36.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from chromadb) (1.36.0)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from chromadb) (0.21.4)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from chromadb) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from chromadb) (1.74.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from chromadb) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from chromadb) (0.16.0)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from chromadb) (33.1.0)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from chromadb) (5.2.0)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from chromadb) (3.11.1)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from chromadb) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from chromadb) (14.1.0)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from chromadb) (4.25.0)
# Requirement already satisfied: six>=1.5 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.2 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.9.0)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from sentence-transformers) (4.55.0)
# Requirement already satisfied: torch>=1.11.0 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from sentence-transformers) (2.7.1)
# Requirement already satisfied: scikit-learn in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from sentence-transformers) (1.7.1)
# Requirement already satisfied: scipy in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from sentence-transformers) (1.16.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from sentence-transformers) (0.34.3)
# Requirement already satisfied: Pillow in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from sentence-transformers) (11.3.0)
# Requirement already satisfied: filelock in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (3.18.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2025.7.34)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.5.3)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.3.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from langchain_community) (3.12.15)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from langchain_community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from langchain_community) (2.10.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from langchain_community) (0.4.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.20.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (0.9.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain_community) (1.1.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community) (1.1.0)
# Requirement already satisfied: pyproject_hooks in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: anyio in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from httpx>=0.27.0->chromadb) (4.10.0)
# Requirement already satisfied: httpcore==1.* in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from httpx>=0.27.0->chromadb) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.16.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from jsonschema>=4.19.0->chromadb) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.26.0)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.40.3)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests-oauthlib in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: durationpy>=0.7 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.1)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from langsmith>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from langsmith>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: coloredlogs in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (25.2.10)
# Requirement already satisfied: protobuf in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (6.31.1)
# Requirement already satisfied: sympy in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.23.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.70.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.36.0 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.36.0)
# Requirement already satisfied: opentelemetry-proto==1.36.0 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.36.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.57b0 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.57b0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from rich>=10.11.0->chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from rich>=10.11.0->chromadb) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: networkx in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.5)
# Requirement already satisfied: jinja2 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from torch>=1.11.0->sentence-transformers) (80.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: click>=8.0.0 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from typer>=0.9.0->chromadb) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.4)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.0)
# Requirement already satisfied: websockets>=10.4 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from anyio->httpx>=0.27.0->chromadb) (1.3.1)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: pyreadline3 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb) (3.5.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from scikit-learn->sentence-transformers) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\zoro\desktop\recommender_music\.env\lib\site-packages (from scikit-learn->sentence-transformers) (3.6.0)
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain.document_loaders import TextLoader
from langchain.text_splitter import CharacterTextSplitter
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import Chroma

# %%
from langchain.schema import Document

# Load back into one Document per song
with open("songs_lyrics.txt", "r", encoding="utf-8") as f:
    songs = f.read().strip().split("\n")

documents = [Document(page_content=song) for song in songs if song.strip()]

# %%
print(len(documents))   # number of songs
print(documents[0].page_content)  # lyrics of first song
# Out:
# 57650
# "Look at her face, it's a wonderful face   And it means something special to me   Look at the way that she smiles when she sees me   How lucky can one fellow be?      She's just my kind of girl, she makes me feel fine   Who could ever believe that she could be mine?   She's just my kind of girl, without her I'm blue   And if she ever leaves me what could I do, what could I do?      And when we go for a walk in the park   And she holds me and squeezes my hand   We'll go on walking for hours and talking   About all the things that we plan      She's just my kind of girl, she makes me feel fine   Who could ever believe that she could be mine?   She's just my kind of girl, without her I'm blue   And if she ever leaves me what could I do, what could I do?"

# %% [markdown]
# In documents, each song's lyrics are on a seperate line.

# %% [markdown]
# #### Reading the dataset containing predicted emotions (useful as metadata for hybrid search)

# %%
import pandas as pd

# Reading the csv file
songs_sentiment_df = pd.read_csv('songs_with_predicted_emotions.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 4
#       1 import pandas as pd
#       3 # Reading the csv file
# ----> 4 songs_sentiment_df = pd.read_csv('songs_with_predicted_emotions.csv')
#
# File c:\Users\zoro\Desktop\Recommender_music\.env\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\zoro\Desktop\Recommender_music\.env\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Users\zoro\Desktop\Recommender_music\.env\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\zoro\Desktop\Recommender_music\.env\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\Users\zoro\Desktop\Recommender_music\.env\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'songs_with_predicted_emotions.csv'

# %% [markdown]
# ##### **Vector database**: Chroma

# %%
# Adding metadata to the lyrics to re-link it to the songs + sentiment info
from langchain.schema import Document

lyrics_song_artist = []

for _, row in songs_sentiment_df.iterrows():
    lyrics = row['text']
    title = row['song']
    artist = row['artist']


    doc = Document(
        page_content=lyrics,
        metadata={
            'title': title,
            'artist': artist
        }
    )
    lyrics_song_artist.append(doc)

# %% [markdown]
# *page_content* → contains clean, consistent lyrics for better similarity search.
#
# *metadata* → retains song title and artist so recommendations can be shown with full context.

# %%
# Use a HuggingFace embedding model (efficient & open-source)
embedding_function = HuggingFaceEmbeddings(
    model_name="all-MiniLM-L6-v2"
)

# Create and persist Chroma DB
db = Chroma.from_documents(
    documents=lyrics_song_artist,
    embedding=embedding_function,
    persist_directory="./chroma_songs_db",
    collection_name="lyrics"
)

# Save the DB to disk
db.persist()
# Out:
# c:\Users\zoro\Desktop\Recommender_music\.env\Lib\site-packages\torch\nn\modules\module.py:1762: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `BertSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs